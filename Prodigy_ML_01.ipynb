# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
data = pd.read_csv('/content/HousePricePrediction.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            2919 non-null   int64
#  1   MSSubClass    2919 non-null   int64
#  2   MSZoning      2915 non-null   object
#  3   LotArea       2919 non-null   int64
#  4   LotConfig     2919 non-null   object
#  5   BldgType      2919 non-null   object
#  6   OverallCond   2919 non-null   int64
#  7   YearBuilt     2919 non-null   int64
#  8   YearRemodAdd  2919 non-null   int64
#  9   Exterior1st   2918 non-null   object
#  10  BsmtFinSF2    2918 non-null   float64
#  11  TotalBsmtSF   2918 non-null   float64
#  12  SalePrice     1460 non-null   float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 296.6+ KB

# %%
col_list=list(data.columns)

# %%
col_list
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotArea',
#  'LotConfig',
#  'BldgType',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'Exterior1st',
#  'BsmtFinSF2',
#  'TotalBsmtSF',
#  'SalePrice']

# %%
data.shape
# Out:
# (2919, 13)

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    plt.boxplot(data[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    Q1=data[col].quantile(0.25)
    Q3=data[col].quantile(0.75)
    IQR=Q3-Q1

    data= data[(data[col] >= Q1-1.5*IQR) & (data[col]<= Q3 + 1.5*IQR)]

# %%
data.shape
# Out:
# (2320, 13)

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    plt.boxplot(data[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    Q1=data[col].quantile(0.25)
    Q3=data[col].quantile(0.75)
    IQR=Q3-Q1

    data= data[(data[col] >= Q1-1.5*IQR) & (data[col]<= Q3 + 1.5*IQR)]

print(data.shape)
# Out:
# (2314, 13)

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    plt.boxplot(data[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    Q1=data[col].quantile(0.25)
    Q3=data[col].quantile(0.75)
    IQR=Q3-Q1

    data= data[(data[col] >= Q1-1.5*IQR) & (data[col]<= Q3 + 1.5*IQR)]

print(data.shape)
# Out:
# (2312, 13)

# %%
for col in col_list:
  if(data[col].dtype== 'int64'):
    plt.boxplot(data[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# Appling the Interquartile Method Three times to remove outliers from the dataset.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in col_list:
  if(data[col].dtype== 'object'):
    data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotArea  LotConfig  BldgType  OverallCond  \
# 0   0          60         3     8450          4         0            5
# 2   2          60         3    11250          4         0            5
# 3   3          70         3     9550          0         0            5
# 4   4          60         3    14260          2         0            5
# 5   5          50         3    14115          4         0            5
#
#    YearBuilt  YearRemodAdd  Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0       2003          2003           12         0.0        856.0   208500.0
# 2       2001          2002           12         0.0        920.0   223500.0
# 3       1915          1970           13         0.0        756.0   140000.0
# 4       2000          2000           12         0.0       1145.0   250000.0
# 5       1993          1995           12         0.0        796.0   143000.0

# %%
data.corr()
# Out:
#                     Id  MSSubClass  MSZoning   LotArea  LotConfig  BldgType  \
# Id            1.000000    0.011848  0.007038 -0.010825   0.018582  0.007388
# MSSubClass    0.011848    1.000000  0.020111 -0.318535   0.037980  0.728649
# MSZoning      0.007038    0.020111  1.000000 -0.100127  -0.010402 -0.010288
# LotArea      -0.010825   -0.318535 -0.100127  1.000000  -0.177053 -0.413425
# LotConfig     0.018582    0.037980 -0.010402 -0.177053   1.000000  0.073983
# BldgType      0.007388    0.728649 -0.010288 -0.413425   0.073983  1.000000
# OverallCond  -0.007075   -0.126875  0.170000 -0.090118  -0.033724 -0.175938
# YearBuilt    -0.009850    0.129834 -0.324092  0.197157   0.009690  0.210739
# YearRemodAdd -0.032866    0.129903 -0.216865  0.139071   0.018765  0.146858
# Exterior1st  -0.017310   -0.029913 -0.046975  0.046035   0.026280 -0.061827
# BsmtFinSF2    0.025820   -0.072057  0.020067  0.060538  -0.009185 -0.020627
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as lr

# %%
x = data.drop('SalePrice',axis=1)
y = data['SalePrice']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
x = imputer.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x = sc.fit_transform(x)

# %%
y = y.fillna(y.mean())

# %%
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.75,random_state=42)

# %%
l_model=lr()

# %%
l_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = l_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,prediction)

# %%
r2
# Out:
# 0.34078061842796326

# %%
mape=mean_absolute_percentage_error(y_test,prediction)

# %%
mape
# Out:
# 0.17569289033882354
